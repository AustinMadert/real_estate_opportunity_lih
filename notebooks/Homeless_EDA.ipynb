# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
zillow = pd.read_csv('data/Neighborhod_MedianValuePerSqft_AllHomes.csv')

# %%
homeless = pd.read_csv('data/Austin_Point_in_Time_Count_2007_to_2017.csv')

# %%
homeless
# Out:
#            Continuum of Care  Year  \
# 0   Austin/Travis County CoC  2007
# 1   Austin/Travis County CoC  2008
# 2   Austin/Travis County CoC  2009
# 3   Austin/Travis County CoC  2010
# 4   Austin/Travis County CoC  2011
# 5   Austin/Travis County CoC  2012
# 6   Austin/Travis County CoC  2013
# 7   Austin/Travis County CoC  2014
# 8   Austin/Travis County CoC  2015
# 9   Austin/Travis County CoC  2016
# 10  Austin/Travis County CoC  2017
# 11  Austin/Travis County CoC  2018
# 12  Austin/Travis County CoC  2007
# 13  Austin/Travis County CoC  2008
# 14  Austin/Travis County CoC  2009
# 15  Austin/Travis County CoC  2010
# 16  Austin/Travis County CoC  2011
# 17  Austin/Travis County CoC  2012
# 18  Austin/Travis County CoC  2013
# 19  Austin/Travis County CoC  2014
# 20  Austin/Travis County CoC  2015
# 21  Austin/Travis County CoC  2016
# 22  Austin/Travis County CoC  2017
# 23  Austin/Travis County CoC  2007
# 24  Austin/Travis County CoC  2008
# ...

# %%
homeless.shape
# Out:
# (73, 6)

# %%
zillow[zillow['City'] == 'Austin']
# Out:
#       RegionID                RegionName    City State              Metro  \
# 392     274685              North Austin  Austin    TX  Austin-Round Rock
# 650     271391             Franklin Park  Austin    TX  Austin-Round Rock
# 731     275057           Pleasant Valley  Austin    TX  Austin-Round Rock
# 754     271652              Windsor Park  Austin    TX  Austin-Round Rock
# 788     271635           West University  Austin    TX  Austin-Round Rock
# 804     416968             West Oak Hill  Austin    TX  Austin-Round Rock
# 941     416969             East Oak Hill  Austin    TX  Austin-Round Rock
# 1014    276540                 Riverside  Austin    TX  Austin-Round Rock
# 1099    271395             Garrison Park  Austin    TX  Austin-Round Rock
# 1316    238833              Wells Branch  Austin    TX  Austin-Round Rock
# 1366    271529               Parker Lane  Austin    TX  Austin-Round Rock
# 1422    271286                 Allandale  Austin    TX  Austin-Round Rock
# ...
